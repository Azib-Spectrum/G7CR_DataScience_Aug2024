# %%
import pandas as pd

# %%
# 1D: Series
# 2D: DataFrames
# 3D: Panels
# 4D: 4D Panels

# %%
tuple1=(3,8,2,9,3,20,39)

# %%
s1=pd.Series(tuple1)
s1

# %%
list1=["grapes",'orange','kivi','mango','apple']
s2=pd.Series(list1)
s2

# %%
s2[2]

# %%
import numpy as np

# %%
arr1=np.array([2,4,6,8])
arr1

# %%
pd.Series(arr1)

# %%
dic1={"Sagar":22,"Darshan":23,"Shiva":24,"Naveen":25,"Rahul":20}

# %%
nam=pd.Series(dic1)
nam

# %%
nam[2]

# %%
nam.size

# %%
nam.shape

# %%
nam.ndim

# %%
nam.index

# %%
nam.values

# %%
cars={'model':['bmw','audi','rangerover','tata','mercedes benz','mahindra'],
      'price':[50,60,75,25,90,13],'color':['black','white','gray','blue','orange','white']}

# %%
cars

# %%
c1=pd.DataFrame(cars)
c1

# %%
type(c1)

# %%
c1['model']

# %%
type(c1['model'])

# %%
np.random.seed(10)
arr2=np.random.randint(25,50,(5,6))
arr2

# %%
student=['yugma','sandhya','prasanna','teja','keerthana']
subjects=['english','maths','science','sanskrit','biology','social']
marks=pd.DataFrame(arr2,index=student,columns=subjects)
marks

# %%
type(marks)

# %%
marks.shape

# %%
marks.size

# %%
marks.ndim

# %%
marks.info()

# %%
marks

# %%
marks['total marks']=marks.sum(axis=1)

# %%
marks

# %%
marks['total']=marks['english']+marks['maths']+marks['science']+marks['sanskrit']+marks['biology']+marks['social']

# %%
marks

# %%
marks["percentage"]=round(((marks["total"]/300)*100),2)
marks

# %%
marks=marks.drop(columns=["total marks"])
marks

# %%
marks.drop(columns=["percentage"],inplace=True)

# %%
marks

# %%
marks=marks.rename(columns={"english":"English","maths":"Maths","science":"Science","sanskrit":"Sanskrit","biology":"Biology","social":"Social","total":"Total"})

# %%
marks

# %%
#marks=marks.drop(index=["teja"])
marks

# %%
# comma separated values

# %%
df=pd.read_csv(r"C:\Users\Ameer\Downloads\G7 CR DataScience\titanic.csv")
# pd.read_csv("C:/Users/Ameer/Downloads/G7 CR DataScience/titanic.csv")
# pd.read_csv("titanic.csv")
df

# %%
df.drop(columns=['PassengerId'],inplace=True)

# %%
df

# %%
# !pip install openpyxl

# %%
super=pd.read_excel(r"C:\Users\Ameer\Downloads\Superstore.xlsx",sheet_name="Returns")
super

# %%
fruits=pd.read_csv(r"C:\Users\Ameer\Downloads\fruit_data_with_colors.txt",sep="\t")
# fruits.columns=[fruits.iloc[0]]
# fruits=fruits[1:].reset_index(drop=True)
# fruits=fruits.rename(columns=fruits.iloc[0]).drop(fruits.index[0]).reset_index(drop=True)
fruits
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
fruits.to_csv("fruits.csv",header=1)

# %%
pd.read_table(r"C:\Users\Ameer\Downloads\fruit_data_with_colors.txt")

# %%
iris=pd.read_html("https://en.wikipedia.org/wiki/Iris_flower_data_set")[0]
iris

# %%
# !pip install lxml

# %%
iris1=pd.read_html(r"C:\Users\Ameer\Downloads\Iris flower data set - Wikipedia.html")[0]
iris1

# %%
iris2=pd.read_csv(r"C:\Users\Ameer\Downloads\G7 CR DataScience\IRIS Test data.txt",sep=";",header=None)
iris2.rename(columns={0:'Sepal Length',1:'T1',2:'Sepal Width',3:'T2',
                      4:'Petal Length',5:'T3',6:'Petal Width',7:'T4',
                      8:'Species'},inplace=True)
iris2

# %%
pq=pd.read_parquet(r"C:\Users\Ameer\Downloads\sample1.parquet")
# pq.columns=pq.iloc[0]
# pq=pq[1:]
# pq.reset_index(drop=True,inplace=True)
# pq

pq1=pd.DataFrame(pq.values[1:],columns=pq.iloc[0])
pq1
# Out:
# 0       first      last
# 0       Jorge     Frank
# 1      Hunter    Moreno
# 2      Esther    Guzman
# 3      Dennis  Stephens
# 4      Nettie  Franklin
# ..        ...       ...
# 95      Brett    Miller
# 96   Adelaide    Phelps
# 97        Leo   Walters
# 98     Samuel   Schmidt
# 99  Elizabeth    Gordon
#
# [100 rows x 2 columns]

# %%
# !pip install pyarrow

# %%
df

# %%
# EDA: Exploratory Data Analysis
# Navigation within the pandas

# %%
d={'id':[6,7,8,9,10],'Employee':['Mr. A','Mr. B','Mr. C','Mr. D','Mr. E']}
a1=pd.DataFrame(d)
a1

# %%
d={'id':[1,2,3,4,5],'Employee':['Mr. X','Mr. Y','Mr. Z','Mr. F','Mr. G']}
a2=pd.DataFrame({})
a2

# %%
pd.concat([a2,a1],ignore_index=True)

# %%
d={'E_id':[1,2,3,4,5],'Employee':['Mr. A','Mr. B','Mr. C','Mr. D','Mr. E']}
a3=pd.DataFrame(d)
a3

# %%
d={'id':[7,2,6,4,5],'Last Name':['Smith','Brown','David','Stark','Renly']}
a4=pd.DataFrame(d)
a4

# %%
pd.merge(a3,a4,how='inner',left_on='E_id',right_on='id')

# %%
pd.merge(a3,a4,how='left',left_on='E_id',right_on='id')

# %%
pd.merge(a3,a4,how='right',left_on='E_id',right_on='id')

# %%
pd.merge(a3,a4,how='outer',left_on='E_id',right_on='id')

# %%
df

# %%
df.shape

# %%
df.duplicated().sum()

# %%
df.isnull().sum()

# %%
# Missing values/ Blank Values
# NaN: Not a Number or Null values

# %%
# Delete the row containing the blank value
# Delete the column containing the blank value
# Fill the blank values: with 0 or fill it with mean value, or median value or mode value

# %%
177/891

# %%
df['Age']=df['Age'].fillna(value=df['Age'].mean())

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df['Embarked']=df['Embarked'].fillna(value=df['Embarked'].mode().values[0])

# %%
df['Embarked'].mode().values[0]

# %%
df['Age'].mean()

# %%
df['Age'].median()

# %%
df['Age'].mode()

# %%
df.isnull().sum()

# %%
# Remove Unwanted Columns(ID)
# Check for duplicates
# Check for Missing or null values
# EDA on individual columns

# %%
df

# %%
df.head()

# %%
df.head(3)

# %%
df.tail()

# %%
df.tail(2)

# %%
df[2:13]

# %%
df.sample(3,random_state=15)

# %%
df[['Ticket','Age','Fare']]

# %%
df.iloc[2:7,3:6]

# %%
df.iloc[[2,3,4,5,6],[3,4,5]]

# %%
df.iloc[[5,12,18,22,631,9,52],[9,2,3]]

# %%
df.loc[[5,12,18,22,631,9,52],['Embarked','Name','Sex']]

# %%
df.columns

# %%
df.index

# %%
df.iloc[2]

# %%
df.iloc[2].Fare

# %%
df.iloc[2].replace(7.925,9)

# %%
df.iloc[2]['Fare']=9.5

# %%
df.iloc[2]

# %%
df.sample()
# Out:
#      Survived  Pclass                          Name   Sex   Age  SibSp  Parch  \
# 515         0       1  Walker, Mr. William Anderson  male  47.0      0      0
#
#     Ticket     Fare Embarked
# 515  36967  34.0208        S

# %%
df.nunique()
# Out:
# Survived      2
# Pclass        3
# Name        891
# Sex           2
# Age          89
# SibSp         7
# Parch         7
# Ticket      681
# Fare        248
# Embarked      3
# dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Survived'].value_counts().index,df['Survived'].value_counts().values)
plt.xticks([0,1])
plt.show()

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
import seaborn as sns

# %%
chart=sns.countplot(x='Survived',data=df)
chart.set_xlabel("Survived vs Not-Survived")
chart.set_ylabel("Count of Passengers")
chart.set_title("Survival Chances")
plt.show()

# %%
df.sample()
# Out:
#      Survived  Pclass                            Name     Sex  Age  SibSp  \
# 448         1       3  Baclini, Miss. Marie Catherine  female  5.0      2
#
#      Parch Ticket     Fare Embarked
# 448      1   2666  19.2583        C

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().sort_index()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.countplot(x='Pclass',data=df)
# sns.catplot(x='Pclass',data=df,kind='count')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.catplot(x='Pclass',data=df,kind='count',palette="pastel")
# sns.catplot(x=df['Pclass'],kind='count')
# Out:
# C:\Users\Ameer\AppData\Local\Temp\ipykernel_25696\4127945429.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Pclass',data=df,kind='count',palette="pastel")

# %%
sns.catplot(x=df['Pclass'],kind='count',hue=df['Survived'],palette="winter")
plt.show()

# %%
sns.catplot(x=df['Pclass'],y=df['Survived'],kind='bar',errorbar=None,order=[3,2,1])
# sns.barplot(x=df['Pclass'],y=df['Survived'])

# %%
sns.catplot(x=df['Pclass'],y=df['Survived'],kind='bar',errorbar=None,hue=df["Sex"],palette="Greens")

# %%
sns.catplot(x=df['Sex'],kind='count',hue=df['Survived'])
plt.show()

# %%
sns.catplot(x=df['Embarked'],kind='count')

# %%
sns.catplot(x=df['Embarked'],kind='count',hue=df['Survived'])

# %%
sns.catplot(x=df['Embarked'],y=df['Survived'],kind='bar',errorbar=None)

# %%
sns.catplot(x=df['Embarked'],kind='count',hue=df['Pclass'])

# %%
sns.catplot(x=df['Embarked'],y=df['Survived'],kind='bar',hue=df['Pclass'],errorbar=None)

# %%
# Majority of passengers were Male
# Majority of passengers were travelling in 3rd Class
# Majority of passengers embarked from Southampton
# Overall.. only 38% of passengers survived.
# Majority of survivers were female.
# People travelling in PClass 1 survived more than any other classes.
# Survival rate in P3 was very bad
# People from Cherboug survived relatively more than people from other cities

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
342/891
# Out:
# 0.3838383838383838

# %%
df.sample()
# Out:
#      Survived  Pclass                           Name   Sex   Age  SibSp  \
# 883         0       2  Banfield, Mr. Frederick James  male  28.0      0
#
#      Parch            Ticket  Fare Embarked
# 883      0  C.A./SOTON 34068  10.5        S

# %%
df['Family']=df['SibSp']+df['Parch']

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch            Ticket     Fare Embarked  \
# ...

# %%
df.sample(10)
# Out:
#      Survived  Pclass                               Name     Sex        Age  \
# 637         0       2                Collyer, Mr. Harvey    male  31.000000
# 219         0       2                 Harris, Mr. Walter    male  30.000000
# 385         0       2          Davies, Mr. Charles Henry    male  18.000000
# 597         0       3                Johnson, Mr. Alfred    male  49.000000
# 20          0       2               Fynney, Mr. Joseph J    male  35.000000
# 119         0       3  Andersson, Miss. Ellis Anna Maria  female   2.000000
# 857         1       1             Daly, Mr. Peter Denis     male  51.000000
# 711         0       1                 Klaber, Mr. Herman    male  29.699118
# 677         1       3            Turja, Miss. Anna Sofia  female  18.000000
# 329         1       1       Hippach, Miss. Jean Gertrude  female  16.000000
#
#      SibSp  Parch        Ticket     Fare Embarked  Family
# 637      1      1    C.A. 31921  26.2500        S       2
# ...

# %%
df.drop(columns=['SibSp','Parch'],inplace=True)

# %%
df.sample(10)
# Out:
#      Survived  Pclass                               Name     Sex        Age  \
# 402         0       3           Jussila, Miss. Mari Aina  female  21.000000
# 315         1       3    Nilsson, Miss. Helmina Josefina  female  26.000000
# 306         1       1            Fleming, Miss. Margaret  female  29.699118
# 37          0       3           Cann, Mr. Ernest Charles    male  21.000000
# 696         0       3                   Kelly, Mr. James    male  44.000000
# 353         0       3          Arnold-Franchi, Mr. Josef    male  25.000000
# 15          1       2   Hewlett, Mrs. (Mary D Kingcome)   female  55.000000
# 546         1       2  Beane, Mrs. Edward (Ethel Clarke)  female  19.000000
# 107         1       3             Moss, Mr. Albert Johan    male  29.699118
# 204         1       3           Cohen, Mr. Gurshon "Gus"    male  18.000000
#
#          Ticket      Fare Embarked  Family
# 402        4137    9.8250        S       1
# 315      347470    7.8542        S       0
# ...

# %%
df['Family'].value_counts()
# Out:
# Family
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: count, dtype: int64

# %%
df['Family'].value_counts().sort_index()
# Out:
# Family
# 0     537
# 1     161
# 2     102
# 3      29
# 4      15
# 5      22
# 6      12
# 7       6
# 10      7
# Name: count, dtype: int64

# %%
df['Family'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Family'>

# %%
df['Age'].describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.displot(x=df['Age'],kde=True)

# %%
import numpy as np
arr6=np.arange(0,86,5)
arr6
# Out:
# array([ 0,  5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80,
#        85])

# %%
x1 = sns.displot(x=df['Age'],kde=True,bins=arr6)

# %%
x1 = sns.displot(x=df['Fare'],kde=True)

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.nunique()
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
sns.scatterplot(x=tips["total_bill"],y=tips["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x=tips["total_bill"],y=tips["tip"],hue=tips["sex"],style=tips["smoker"],size=tips["size"])
plt.xticks(np.arange(0,51,5))
plt.show()

# %%
# Univariate Analysis
# Bivariate Analysis

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter',color='red')
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
sns.jointplot(x='total_bill',y='tip',data=tips,kind='resid')

# %%
sns.pairplot(tips,hue='smoker')

# %%
tips.sample()
# Out:
#      total_bill  tip   sex smoker  day    time  size
# 159       16.49  2.0  Male     No  Sun  Dinner     4

# %%
pd.crosstab(df['Pclass'],df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']),cmap="Blues")
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
pd.pivot_table(df,values=['Fare'],columns=['Survived'],index=['Pclass'],aggfunc='mean')
# Out:
#                Fare
# Survived          0          1
# Pclass
# 1         64.684007  95.608029
# 2         19.412328  22.055700
# 3         13.669364  13.694887

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x=tips["day"],y=tips["total_bill"],palette="summer")
# Out:
# C:\Users\Ameer\AppData\Local\Temp\ipykernel_25696\1314256979.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x=tips["day"],y=tips["total_bill"],palette="summer")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x=tips["day"],y=tips["total_bill"],palette="summer")
# Out:
# C:\Users\Ameer\AppData\Local\Temp\ipykernel_25696\875821416.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x=tips["day"],y=tips["total_bill"],palette="summer")
# <Axes: xlabel='day', ylabel='total_bill'>
