# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("laptop_price.csv",encoding='latin')
df
# UnicodeDecodeError: 'utf-8' codec can't decode
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.sample()
# Out:
#     Company      Product   TypeName  Inches             ScreenResolution  \
# 642  Lenovo  ThinkPad X1  Ultrabook    14.0  IPS Panel Full HD 1920x1080
#
#                             Cpu   Ram     Memory                    Gpu  \
# 642  Intel Core i7 7500U 2.7GHz  16GB  512GB SSD  Intel HD Graphics 620
#
#           OpSys  Weight  Price_euros
# 642  Windows 10  1.14kg       2450.0

# %%
df.duplicated().sum()
# Out:
# np.int64(28)

# %%
df[df.duplicated()]
# Out:
#      Company                                    Product            TypeName  \
# 1275    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1276    Dell                              Inspiron 3567            Notebook
# 1277    Acer                             Aspire ES1-531            Notebook
# 1278    Dell                              Inspiron 3552            Notebook
# 1279  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1280      HP                        Pavilion 15-AW003nv            Notebook
# 1281    Dell                              Inspiron 3567            Notebook
# 1282      HP                           Stream 11-Y000na             Netbook
# 1283    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1284  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1285  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1286  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1287      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1288    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# 1289    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1290    Dell                              Inspiron 3567            Notebook
# 1291    Acer                             Aspire ES1-531            Notebook
# 1292    Dell                              Inspiron 3552            Notebook
# 1293  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1294      HP                        Pavilion 15-AW003nv            Notebook
# 1295    Dell                              Inspiron 3567            Notebook
# 1296      HP                           Stream 11-Y000na             Netbook
# 1297    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1298  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1301      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Inches                            ScreenResolution  \
# 1275    13.3                 IPS Panel Full HD 1920x1080
# 1276    15.6                                    1366x768
# 1277    15.6                                    1366x768
# 1278    15.6                                    1366x768
# 1279    15.6                 IPS Panel Full HD 1920x1080
# 1280    15.6                           Full HD 1920x1080
# 1281    15.6                                    1366x768
# 1282    11.6                                    1366x768
# 1283    15.6                                    1366x768
# 1284    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1285    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286    14.0                                    1366x768
# 1287    15.6                                    1366x768
# 1288    15.6                                    1366x768
# 1289    13.3                 IPS Panel Full HD 1920x1080
# 1290    15.6                                    1366x768
# 1291    15.6                                    1366x768
# 1292    15.6                                    1366x768
# 1293    15.6                 IPS Panel Full HD 1920x1080
# 1294    15.6                           Full HD 1920x1080
# 1295    15.6                                    1366x768
# 1296    11.6                                    1366x768
# 1297    15.6                                    1366x768
# 1298    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300    14.0                                    1366x768
# 1301    15.6                                    1366x768
# 1302    15.6                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1275              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                           Gpu       OpSys  Weight  Price_euros
# 1275    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1276    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1277    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1278        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1279  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1280       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1281       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1282    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1283      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1284    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1285    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1286        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1287       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1288        Intel HD Graphics  Windows 10   2.2kg       369.00
# 1289    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1290    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1291    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1292        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1293  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1294       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1295       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1296    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1297      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1298    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302        Intel HD Graphics  Windows 10   2.2kg       369.00

# %%
df.drop_duplicates(ignore_index=True,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   Product           1275 non-null   object
#  2   TypeName          1275 non-null   object
#  3   Inches            1275 non-null   float64
#  4   ScreenResolution  1275 non-null   object
#  5   Cpu               1275 non-null   object
#  6   Ram               1275 non-null   object
#  7   Memory            1275 non-null   object
#  8   Gpu               1275 non-null   object
#  9   OpSys             1275 non-null   object
#  10  Weight            1275 non-null   object
#  11  Price_euros       1275 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 119.7+ KB

# %%
df['Price']=round(df['Price_euros']*91.63).astype('int')
df['Price']
# Out:
# 0       122756
# 1        82370
# 2        52687
# 3       232507
# 4       165264
#          ...
# 1270     58460
# 1271    137353
# 1272     20983
# 1273     70005
# 1274     33811
# Name: Price, Length: 1275, dtype: int64

# %%
df.sample(3)
# Out:
#     Company            Product   TypeName  Inches       ScreenResolution  \
# 971    Dell     Latitude E7470  Ultrabook    14.0  Touchscreen 2560x1440
# 364  Lenovo  IdeaPad 320-15ISK   Notebook    15.6               1366x768
# 373  Lenovo  IdeaPad 110-17ACL   Notebook    17.3               1600x900
#
#                             Cpu  Ram     Memory                    Gpu  \
# 971  Intel Core i7 6600U 2.6GHz  8GB  256GB SSD  Intel HD Graphics 520
# 364    Intel Core i3 6006U 2GHz  8GB  256GB SSD  Nvidia GeForce 920MX
# 373   AMD A8-Series 7410 2.2GHz  4GB  128GB SSD          AMD Radeon R5
#
#           OpSys Weight  Price_euros   Price
# 971  Windows 10  1.5kg      1962.98  179868
# 364       No OS  2.2kg       499.00   45723
# 373  Windows 10  2.6kg       489.00   44807

# %%
df.drop(columns=['Price_euros'],inplace=True)

# %%
df['Price'].describe()
# Out:
# count      1275.000000
# mean     103997.181961
# std       64209.924591
# min       15944.000000
# 25%       55803.000000
# 50%       90622.000000
# 75%      137124.500000
# max      558851.000000
# Name: Price, dtype: float64

# %%
sns.displot(df['Price'],kde=True)

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df.sample()
# Out:
#     Company        Product  TypeName  Inches             ScreenResolution  \
# 715  Lenovo  Thinkpad E470  Notebook    14.0  IPS Panel Full HD 1920x1080
#
#                             Cpu  Ram     Memory                   Gpu  \
# 715  Intel Core i5 7200U 2.5GHz  8GB  256GB SSD  Nvidia GeForce 920MX
#
#           OpSys  Weight  Price
# 715  Windows 10  1.87kg  78533

# %%
df.nunique()
# Out:
# Company              19
# Product             618
# TypeName              6
# Inches               18
# ScreenResolution     40
# Cpu                 118
# Ram                   9
# Memory               39
# Gpu                 110
# OpSys                 9
# Weight              179
# Price               790
# dtype: int64

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
9+7+7+6+4+4+3+3+3+3+2
# 1275-51=1224
51/1275
# Out:
# 0.04

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
df=df[df.groupby('Company').Company.transform('count')>10]

# %%
df.shape
# Out:
# (1224, 12)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                    1366x768
# 1273                                    1366x768
# 1274                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1270            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1271            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1272  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1273            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight   Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg  122756
# 1           Intel HD Graphics 6000       macOS  1.34kg   82370
# 2            Intel HD Graphics 620       No OS  1.86kg   52687
# 3               AMD Radeon Pro 455       macOS  1.83kg  232507
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  165264
# ...                            ...         ...     ...     ...
# 1270         Intel HD Graphics 520  Windows 10   1.8kg   58460
# 1271         Intel HD Graphics 520  Windows 10   1.3kg  137353
# 1272             Intel HD Graphics  Windows 10   1.5kg   20983
# 1273            AMD Radeon R5 M330  Windows 10  2.19kg   70005
# 1274             Intel HD Graphics  Windows 10   2.2kg   33811
#
# [1224 rows x 12 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
# df['Company'].value_counts().sort_index()
# df['Company'].value_counts().sort_values()
df['Company'].value_counts()
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
df['Company'].value_counts().index
# Out:
# Index(['Dell', 'Lenovo', 'HP', 'Asus', 'Acer', 'MSI', 'Toshiba', 'Apple'], dtype='object', name='Company')

# %%
df['Company'].value_counts().plot(kind='bar')
# df['Company'].value_counts().sort_index().plot(kind='bar)
# Out:
# <Axes: xlabel='Company'>

# %%
df['Company'].value_counts().index
# Out:
# Index(['Dell', 'Lenovo', 'HP', 'Asus', 'Acer', 'MSI', 'Toshiba', 'Apple'], dtype='object', name='Company')

# %%
sns.catplot(x=df['Company'],kind='count',order=df['Company'].value_counts().index)  #Descending order of the bars
# sns.catplot(x=df['Company'],kind='count',order=df['Company'].value_counts().sort_values().index)  #Ascending order of the bars

# %%
df.groupby('Company')['Price'].mean().sort_values(ascending=False)
# Out:
# Company
# MSI        158419.759259
# Apple      143327.571429
# Toshiba    116169.666667
# Dell       109885.003436
# Asus       102976.434211
# Lenovo     100230.560554
# HP          98989.197761
# Acer        58044.346535
# Name: Price, dtype: float64

# %%
company_sorted_price=df.groupby('Company')['Price'].mean().sort_values(ascending=False).index
company_sorted_price
# Out:
# Index(['MSI', 'Apple', 'Toshiba', 'Dell', 'Asus', 'Lenovo', 'HP', 'Acer'], dtype='object', name='Company')

# %%
sns.catplot(x=df['Company'],kind='bar',y=df['Price'],errorbar=None,order=company_sorted_price,palette='summer')
# Out:
# C:\Users\Ameer\AppData\Local\Temp\ipykernel_26868\492131643.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x=df['Company'],kind='bar',y=df['Price'],errorbar=None,order=company_sorted_price,palette='summer')

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                         30
# Inspiron 3567                                  25
# 250 G6                                         21
# Vostro 3568                                    19
# Legion Y520-15IKBN                             19
#                                                ..
# PL60 7RD                                        1
# X553SA-XX021T (N3050/4GB/500GB/W10)             1
# V110-15ISK (i5-6200U/4GB/500GB/No               1
# UX410UA-GV097T (i3-7100U/4GB/256GB/FHD/W10)     1
# B51-80 (i7-6500U/4GB/1008GB/FHD/W7)             1
# Name: count, Length: 589, dtype: int64

# %%
df.drop(columns=['Product'],inplace=True)
# Out:
# C:\Users\Ameer\AppData\Local\Temp\ipykernel_26868\163803204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Product'],inplace=True)

# %%
df.sample()
# Out:
#     Company TypeName  Inches ScreenResolution  \
# 665    Acer  Netbook    11.6         1366x768
#
#                                       Cpu  Ram              Memory  \
# 665  Intel Celeron Dual Core N3050 1.6GHz  4GB  32GB Flash Storage
#
#                    Gpu       OpSys Weight  Price
# 665  Intel HD Graphics  Windows 10  1.4kg  24648

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
df.groupby('TypeName')['Price'].mean().sort_values(ascending=False)
# Out:
# TypeName
# Workstation           208949.310345
# Gaming                153176.900000
# Ultrabook             142045.450292
# 2 in 1 Convertible    119070.359649
# Notebook               72928.283430
# Netbook                63386.272727
# Name: Price, dtype: float64

# %%
df.groupby('TypeName')['Price'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
type_sorted_price=df.groupby('TypeName')['Price'].mean().sort_values(ascending=False).index
sns.barplot(x=df['TypeName'],y=df['Price'],errorbar=None,width=0.6,order=type_sorted_price)
plt.xticks(rotation=90)
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
sns.kdeplot(df['Inches'])
# Out:
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
inches_sorted_price=df.groupby('Inches')['Price'].mean().sort_values(ascending=False).index
sns.barplot(x=df['Inches'],y=df['Price'],errorbar=None,width=0.6,order=inches_sorted_price)
plt.xticks(rotation=90)
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# 1920x1080                                          2
# IPS Panel Quad HD+ 3200x1800                       2
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Full HD 1366x768                         1
# IPS Panel Full HD 2560x1440                        1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
# df['IPS']
# df['Touchscreen']
# df['X_res']
# df['Y_res']

# %%
a="IS Panel Quad HD+ 3200x1800"
(lambda a:1 if "ips" in a.lower() else 0)(a)
# Out:
# 0

# %%
df['IPS']=df['ScreenResolution'].apply(lambda a:1 if "ips" in a.lower() else 0)
df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if "touch" in a.lower() else 0)
# Out:
# C:\Users\Ameer\AppData\Local\Temp\ipykernel_26868\1461934196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IPS']=df['ScreenResolution'].apply(lambda a:1 if "ips" in a.lower() else 0)
# C:\Users\Ameer\AppData\Local\Temp\ipykernel_26868\1461934196.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if "touch" in a.lower() else 0)

# %%
df.sample(5)
# Out:
#     Company   TypeName  Inches                               ScreenResolution  \
# 17    Apple  Ultrabook    15.4             IPS Panel Retina Display 2880x1800
# 124    Asus   Notebook    14.0                                       1366x768
# 760    Dell   Notebook    15.6                                       1366x768
# 143      HP  Ultrabook    12.5  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 229    Asus     Gaming    17.3                              Full HD 1920x1080
#
#                              Cpu   Ram                Memory  \
# 17          Intel Core i7 2.9GHz  16GB             512GB SSD
# 124     AMD E-Series 6110 1.5GHz   4GB              64GB SSD
# 760   Intel Core i5 7200U 2.5GHz   8GB             128GB SSD
# 143     Intel Core M 6Y75 1.2GHz   8GB             512GB SSD
# 229  Intel Core i7 7820HK 2.9GHz  32GB  512GB SSD +  1TB HDD
#
#                          Gpu         OpSys  Weight   Price  IPS  Touchscreen
# 17        AMD Radeon Pro 560         macOS  1.83kg  261879    1            0
# 124            AMD Radeon R2  Windows 10 S  1.65kg   25472    0            0
# 760    Intel HD Graphics 620    Windows 10  1.95kg   74220    0            0
# 143    Intel HD Graphics 515    Windows 10  0.97kg  184543    1            1
# 229  Nvidia GeForce GTX 1080    Windows 10   4.7kg  356441    0            0

# %%
a1="IPS Panel 4K Ultra HD / Touchscreen 3840x2160"
int(a1.split()[-1].split('x')[0])
# Out:
# 3840

# %%
df['X_res']=df['ScreenResolution'].apply(lambda a1:a1.split()[-1].split('x')[0]).astype('int')
df['Y_res']=df['ScreenResolution'].apply(lambda a1:a1.split()[-1].split('x')[1]).astype('int')

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches                         Cpu  Ram     Memory  \
# 551  Lenovo  Notebook    15.6  Intel Core i5 7200U 2.5GHz  8GB  256GB SSD
#
#                        Gpu       OpSys Weight  Price  IPS  Touchscreen  X_res  \
# 551  Intel HD Graphics 620  Windows 10  2.3kg  76053    0            0   1920
#
#      Y_res
# 551   1080

# %%
df.nunique()
# Out:
# Company          8
# TypeName         6
# Inches          15
# Cpu            111
# Ram              9
# Memory          38
# Gpu            108
# OpSys            9
# Weight         175
# Price          774
# IPS              2
# Touchscreen      2
# X_res            9
# Y_res            8
# dtype: int64

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz              183
# Intel Core i7 7700HQ 2.8GHz             142
# Intel Core i7 7500U 2.7GHz              124
# Intel Core i5 8250U 1.6GHz               71
# Intel Core i7 8550U 1.8GHz               71
#                                        ...
# Intel Pentium Dual Core 4405Y 1.5GHz      1
# Intel Core M 6Y54 1.1GHz                  1
# AMD E-Series 9000 2.2GHz                  1
# Intel Core M 6Y30 0.9GHz                  1
# AMD A9-Series 9410 2.9GHz                 1
# Name: count, Length: 111, dtype: int64

# %%
df['Cpu_mid']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df['Cpu_mid'].nunique()
# Out:
# C:\Users\Ameer\AppData\Local\Temp\ipykernel_26868\4230600363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu_mid']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
# 36

# %%
df['Cpu_mid'].value_counts()
# Out:
# Cpu_mid
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A6-Series A6-9220         2
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD E-Series 9000e            1
# AMD E-Series E2-6110          1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# Intel Atom x5-Z8350           1
# AMD Ryzen 1600                1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000             1
# AMD A9-Series 9410            1
# Name: count, dtype: int64

# %%
# Intel Core i7
# Intel Core i5
# Intel Core i3
# Intel Core M
# Intel Pentium
# Intel Celeron
# Intel Atom
# Intel Xeon
# AMD A-Series
# AMD F-Series
# AMD E-Series
# AMD Ryzen Series

# %%
def fetch_processor(text):
    if text=="Intel Core i7" or text=="Intel Core i5" or text=="Intel Core i3" or text=="Intel Core M":
        return text
    elif text.split()[0]=="Intel":
        return " ".join(text.split()[0:2])
    elif text.split()[0]=="AMD":
        if text.split()[1][0]=="R":
            return "AMD Ryzen Series"
        elif text.split()[1][0]=="A":
            return "AMD A-Series"
        elif text.split()[1][0]=="F":
            return "AMD F-Series"
        elif text.split()[1][0]=="E":
            return "AMD E-Series"
        else:
            return "Other AMD Processor"
    else:
        return "Other Processor"

# %%
df['Cpu_mid']=df['Cpu_mid'].apply(fetch_processor)

# %%
df['Cpu_mid'].value_counts()
# Out:
# Cpu_mid
# Intel Core i7       493
# Intel Core i5       411
# Intel Core i3       134
# Intel Celeron        71
# AMD A-Series         45
# Intel Pentium        30
# Intel Core M         16
# AMD E-Series          9
# Intel Atom            5
# AMD Ryzen Series      4
# Intel Xeon            4
# AMD F-Series          2
# Name: count, dtype: int64

# %%
df[['Cpu','Cpu_mid']].sample()
# Out:
#                                Cpu     Cpu_mid
# 717  Intel Xeon E3-1535M v5 2.9GHz  Intel Xeon

# %%
df['Cpu']=df['Cpu_mid']

# %%
df.drop(columns=['Cpu_mid'],inplace=True)

# %%
df.sample()
# Out:
#      Company  TypeName  Inches            Cpu  Ram              Memory  \
# 1083    Asus  Notebook    14.0  Intel Celeron  4GB  32GB Flash Storage
#
#                         Gpu       OpSys Weight  Price  IPS  Touchscreen  \
# 1083  Intel HD Graphics 500  Windows 10  1.5kg  25473    0            0
#
#       X_res  Y_res
# 1083   1366    768

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
cpu_sort_price=df.groupby('Cpu')['Price'].mean().sort_values(ascending=False).index
sns.barplot(x=df['Cpu'],y=df['Price'],errorbar=None,order=cpu_sort_price)
plt.xticks(rotation=90)
plt.show()

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')

# %%
df.sample(2)
# Out:
#     Company            TypeName  Inches            Cpu  Ram     Memory  \
# 545    Dell            Notebook    15.6  Intel Core i5    4  500GB HDD
# 827  Lenovo  2 in 1 Convertible    13.3  Intel Core i7    8  256GB SSD
#
#                        Gpu       OpSys  Weight   Price  IPS  Touchscreen  \
# 545  Intel HD Graphics 620  Windows 10    1.93   87873    0            0
# 827  Intel HD Graphics 620  Windows 10    1.37  178678    1            1
#
#      X_res  Y_res
# 545   1366    768
# 827   1920   1080

# %%
df['Ram'].value_counts().sort_index()
# Out:
# Ram
# 2      14
# 4     351
# 6      34
# 8     595
# 12     25
# 16    186
# 24      3
# 32     15
# 64      1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'],errorbar=None)
plt.show()

# %%
df['Weight'].describe()
# Out:
# count    1224.000000
# mean        2.063204
# std         0.663863
# min         0.690000
# 25%         1.597500
# 50%         2.060000
# 75%         2.320000
# max         4.700000
# Name: Weight, dtype: float64

# %%
sns.kdeplot(df['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company  TypeName  Inches         Cpu  Ram   Memory                   Gpu  \
# 585  Lenovo  Notebook    15.6  Intel Xeon   32  1TB SSD  Nvidia Quadro M2200M
#
#           OpSys  Weight   Price  IPS  Touchscreen  X_res  Y_res
# 585  Windows 10     2.5  448895    1            0   3840   2160

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    885
# 1    339
# Name: count, dtype: int64

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'],errorbar=None,width=0.6)
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1055
# 1     169
# Name: count, dtype: int64

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Windows 10 S       2
# Android            2
# Name: count, dtype: int64

# %%
# Windows 10
# Windows 7
# MacOS
# No OS/Linux/Others

# %%
def fetch_os(text):
    if text=="Windows 10" or text=="Windows 10 S":
        return "Windows 10"
    elif text=="Windows 7":
        return text
    elif text=="macOS" or text=="Mac OS X":
        return "MacOS"
    else:
        return "No OS/Linux/Others"

# %%
df['OpSys']=df['OpSys'].apply(fetch_os)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10            1013
# No OS/Linux/Others     145
# Windows 7               45
# MacOS                   21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
sns.barplot(x=df['OpSys'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# AMD Radeon R5 M315           1
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel     666
# Nvidia    385
# AMD       173
# Name: count, dtype: int64

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
sns.barplot(x=df['Gpu'],y=df['Price'],errorbar=None)
# Out:
# <Axes: xlabel='Gpu', ylabel='Price'>

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 256GB SSD +  2TB HDD              10
# 64GB Flash Storage                10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 1TB SSD +  1TB HDD                 2
# 512GB Flash Storage                2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 512GB SSD +  512GB SSD             1
# 64GB SSD                           1
# 64GB Flash Storage +  1TB HDD      1
# 512GB SSD +  256GB SSD             1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# Step by Step approach, followed below this code block

# df['Memory']=df['Memory'].astype(str).replace('\.0',"",regex=True)
# df['Memory']=df['Memory'].str.replace("GB","")
# df['Memory']=df['Memory'].str.replace("TB","000")

# new=df['Memory'].str.split('+',expand=True)
# df['first']=new[0]
# df['first']=df['first'].str.strip()
# df['second']=new[1]

# df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
# df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
# df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
# df['Layer1Flash']=df['first'].apply(lambda x:1 if "Flash" in x else 0)

# df['first']=df['first'].str.replace(r'\D','',regex=True)    #\D indicates all non-numeric values(as per regex)
# df['second'].fillna("0",inplace=True)

# df['Layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
# df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
# df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
# df['Layer2Flash']=df['second'].apply(lambda x:1 if "Flash" in x else 0)

# df['second']=df['second'].str.replace(r'\D','',regex=True)

# df['first']=df['first'].astype('int')
# df['second']=df['second'].astype('int')

# df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
# df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
# df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
# df['Flash_Storage']=df['first']*df['Layer1Flash']+df['second']*df['Layer2Flash']

# df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash',
#                  'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash'],inplace=True)

# %%
df['Memory']=df['Memory'].astype(str).replace('\.0',"",regex=True)
df['Memory']=df['Memory'].str.replace("GB","")
df['Memory']=df['Memory'].str.replace("TB","000")

# %%
new=df['Memory'].str.split('+',expand=True)
df['first']=new[0]
df['first']=df['first'].str.strip()
df['second']=new[1]

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256 SSD                         393
# 1000 HDD                        215
# 500 HDD                         124
# 512 SSD                         105
# 128 SSD +  1000 HDD              93
# 256 SSD +  1000 HDD              73
# 128 SSD                          71
# 32 Flash Storage                 29
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         12
# 64 Flash Storage                 10
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 1000 Hybrid                       7
# 16 Flash Storage                  6
# 180 SSD                           5
# 128 Flash Storage                 4
# 512 SSD +  2000 HDD               3
# 16 SSD                            3
# 256 SSD +  256 SSD                2
# 512 Flash Storage                 2
# 128 SSD +  2000 HDD               2
# 32 SSD                            2
# 256 SSD +  500 HDD                2
# 1000 SSD +  1000 HDD              2
# 64 SSD                            1
# 512 SSD +  256 SSD                1
# 512 SSD +  512 SSD                1
# 1000 HDD +  1000 HDD              1
# 64 Flash Storage +  1000 HDD      1
# 128 HDD                           1
# 240 SSD                           1
# 8 SSD                             1
# 508 Hybrid                        1
# 512 SSD +  1000 Hybrid            1
# 256 SSD +  1000 Hybrid            1
# Name: count, dtype: int64

# %%
# 256GB SSD +  1.0TB Hybrid   
# 256 SSD +  1000 Hybrid

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches            Cpu  Ram  \
# 758   Lenovo  2 in 1 Convertible    14.0  Intel Core i5    8
# 260   Lenovo            Notebook    15.6  Intel Core i7    8
# 1077  Lenovo  2 in 1 Convertible    10.1     Intel Atom    4
# 604     Dell              Gaming    15.6  Intel Core i7   16
# 346     Dell            Notebook    15.6  Intel Core i7    8
#
#                    Memory     Gpu       OpSys  Weight   Price  IPS  \
# 758               256 SSD   Intel  Windows 10    1.42  213498    1
# 260               256 SSD   Intel  Windows 10    2.05   80634    0
# 1077     64 Flash Storage   Intel  Windows 10    0.69   43891    1
# 604   256 SSD +  1000 HDD  Nvidia  Windows 10    2.62  135521    0
# 346   128 SSD +  2000 HDD     AMD  Windows 10    2.02   88964    0
#
#       Touchscreen  X_res  Y_res             first      second  Layer1HDD  \
# 758             1   2560   1440           256 SSD        None          0
# 260             0   1920   1080           256 SSD        None          0
# 1077            1   1920   1200  64 Flash Storage        None          0
# 604             0   1920   1080           256 SSD    1000 HDD          0
# 346             0   1920   1080           128 SSD    2000 HDD          0
#
#       Layer1SSD  Layer1Hybrid  Layer1Flash
# 758           1             0            0
# 260           1             0            0
# 1077          0             0            1
# 604           1             0            0
# 346           1             0            0

# %%
df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash']=df['first'].apply(lambda x:1 if "Flash" in x else 0)

# %%
df['first']=df['first'].str.replace(r'\D','',regex=True)    #\D indicates all non-numeric values(as per regex)
df['second'].fillna("0",inplace=True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches            Cpu  Ram  \
# 380   Lenovo  2 in 1 Convertible    14.0  Intel Core i7   16
# 1074    Dell            Notebook    15.6  Intel Core i5    4
# 1017     MSI              Gaming    15.6  Intel Core i7   16
# 888   Lenovo  2 in 1 Convertible    13.3  Intel Core i7   16
# 941   Lenovo              Gaming    15.6  Intel Core i7    8
#
#                    Memory     Gpu               OpSys  Weight   Price  IPS  \
# 380               512 SSD   Intel          Windows 10    1.42  229900    0
# 1074              500 HDD   Intel  No OS/Linux/Others    2.09   47980    0
# 1017  256 SSD +  1000 HDD  Nvidia          Windows 10    1.80  176754    0
# 888              1000 SSD   Intel          Windows 10    1.30  164842    1
# 941   128 SSD +  1000 HDD  Nvidia          Windows 10    2.50  108948    1
#
#       Touchscreen  X_res  Y_res first      second  Layer1HDD  Layer1SSD  \
# 380             1   2560   1440   512           0          0          1
# 1074            0   1366    768   500           0          1          0
# 1017            0   1920   1080   256    1000 HDD          0          1
# 888             1   3200   1800  1000           0          0          1
# 941             0   1920   1080   128    1000 HDD          0          1
#
#       Layer1Hybrid  Layer1Flash
# 380              0            0
# 1074             0            0
# 1017             0            0
# 888              0            0
# 941              0            0

# %%
df['Layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash']=df['second'].apply(lambda x:1 if "Flash" in x else 0)

df['second']=df['second'].str.replace(r'\D','',regex=True)

# %%
df['first']=df['first'].astype('int')
df['second']=df['second'].astype('int')

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches            Cpu  Ram  \
# 877       HP           Ultrabook    13.3  Intel Core i7    8
# 331     Dell            Notebook    15.6  Intel Celeron    4
# 474     Asus              Gaming    15.6  Intel Core i7    8
# 256     Dell  2 in 1 Convertible    15.6  Intel Core i5    8
# 1127  Lenovo            Notebook    15.6  Intel Core i7    4
#
#                    Memory     Gpu               OpSys  Weight   Price  ...  \
# 877               256 SSD   Intel          Windows 10    1.39  105283  ...
# 331               500 HDD   Intel  No OS/Linux/Others    2.20   25189  ...
# 474   128 SSD +  1000 HDD  Nvidia          Windows 10    1.99  123700  ...
# 256               256 SSD   Intel          Windows 10    2.67   73212  ...
# 1127          1000 Hybrid   Intel           Windows 7    2.32   75595  ...
#
#       first  second  Layer1HDD  Layer1SSD  Layer1Hybrid  Layer1Flash  \
# 877     256       0          0          1             0            0
# 331     500       0          1          0             0            0
# 474     128    1000          0          1             0            0
# 256     256       0          0          1             0            0
# 1127   1000       0          0          0             1            0
#
#       Layer2HDD  Layer2SSD  Layer2Hybrid  Layer2Flash
# 877           0          0             0            0
# 331           0          0             0            0
# 474           1          0             0            0
# 256           0          0             0            0
# 1127          0          0             0            0
#
# [5 rows x 24 columns]

# %%
df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['Flash_Storage']=df['first']*df['Layer1Flash']+df['second']*df['Layer2Flash']

# %%
df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash',
                 'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash'],inplace=True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches            Cpu  Ram  \
# 1002    Asus             Netbook    11.6  Intel Celeron    4
# 256     Dell  2 in 1 Convertible    15.6  Intel Core i5    8
# 701       HP            Notebook    15.6   AMD A-Series    6
# 1120     MSI              Gaming    15.6  Intel Core i7    8
# 385     Dell            Notebook    15.6  Intel Core i7    8
#
#                    Memory     Gpu               OpSys  Weight  Price  IPS  \
# 1002     16 Flash Storage   Intel  No OS/Linux/Others    1.20  26380    0
# 256               256 SSD   Intel          Windows 10    2.67  73212    0
# 701   128 SSD +  1000 HDD     AMD          Windows 10    2.10  59560    0
# 1120             1000 HDD  Nvidia          Windows 10    2.20  76878    1
# 385               256 SSD     AMD  No OS/Linux/Others    2.33  71368    0
#
#       Touchscreen  X_res  Y_res   HDD  SSD  Hybrid  Flash_Storage
# 1002            0   1366    768     0    0       0             16
# 256             1   1920   1080     0  256       0              0
# 701             0   1920   1080  1000  128       0              0
# 1120            0   1920   1080  1000    0       0              0
# 385             0   1920   1080     0  256       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.corr(numeric_only=True)
# Out:
#                  Inches       Ram    Weight     Price       IPS  Touchscreen  \
# Inches         1.000000  0.239155  0.824959  0.055330 -0.104090    -0.359497
# Ram            0.239155  1.000000  0.394187  0.726639  0.223322     0.094037
# Weight         0.824959  0.394187  1.000000  0.212038  0.038753    -0.291506
# Price          0.055330  0.726639  0.212038  1.000000  0.289225     0.161443
# IPS           -0.104090  0.223322  0.038753  0.289225  1.000000     0.154500
# Touchscreen   -0.359497  0.094037 -0.291506  0.161443  0.154500     1.000000
# X_res         -0.057739  0.415731 -0.025155  0.553707  0.283969     0.320954
# Y_res         -0.071772  0.412278 -0.036765  0.552963  0.294360     0.317174
# HDD            0.525077  0.106175  0.503765 -0.093770 -0.087397    -0.195492
# SSD           -0.114322  0.589636 -0.063144  0.654751  0.228186     0.240469
# Hybrid         0.050989  0.052774  0.105129  0.025523 -0.013349    -0.035892
# Flash_Storage -0.230659 -0.047725 -0.178962 -0.023384  0.074771    -0.012073
#
#                   X_res     Y_res       HDD       SSD    Hybrid  Flash_Storage
# Inches        -0.057739 -0.071772  0.525077 -0.114322  0.050989      -0.230659
# Ram            0.415731  0.412278  0.106175  0.589636  0.052774      -0.047725
# Weight        -0.025155 -0.036765  0.503765 -0.063144  0.105129      -0.178962
# Price          0.553707  0.552963 -0.093770  0.654751  0.025523      -0.023384
# IPS            0.283969  0.294360 -0.087397  0.228186 -0.013349       0.074771
# Touchscreen    0.320954  0.317174 -0.195492  0.240469 -0.035892      -0.012073
# X_res          1.000000  0.997454 -0.109044  0.523882 -0.000097      -0.013602
# Y_res          0.997454  1.000000 -0.115936  0.518090 -0.000967       0.020131
# HDD           -0.109044 -0.115936  1.000000 -0.407685 -0.073848      -0.112475
# SSD            0.523882  0.518090 -0.407685  1.000000 -0.050250      -0.140474
# Hybrid        -0.000097 -0.000967 -0.073848 -0.050250  1.000000      -0.012602
# Flash_Storage -0.013602  0.020131 -0.112475 -0.140474 -0.012602       1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),cmap='gray')
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)['Price'].sort_values(ascending=False)
# Out:
# Price            1.000000
# Ram              0.726639
# SSD              0.654751
# X_res            0.553707
# Y_res            0.552963
# IPS              0.289225
# Weight           0.212038
# Touchscreen      0.161443
# Inches           0.055330
# Hybrid           0.025523
# Flash_Storage   -0.023384
# HDD             -0.093770
# Name: Price, dtype: float64

# %%
# Inches
# X_res
# Y_res

# %%
# 1920x1080
# 1800x1040

# Pixel Density(ppi)
#

# %%
df['PPI']=round(np.sqrt(df['X_res']**2+df['Y_res']**2)/df['Inches']).astype('int')

# %%
df.corr(numeric_only=True)['Price'].sort_values(ascending=False)
# Out:
# Price            1.000000
# Ram              0.726639
# SSD              0.654751
# X_res            0.553707
# Y_res            0.552963
# PPI              0.483821
# IPS              0.289225
# Weight           0.212038
# Touchscreen      0.161443
# Inches           0.055330
# Hybrid           0.025523
# Flash_Storage   -0.023384
# HDD             -0.093770
# Name: Price, dtype: float64

# %%
df.drop(columns=['X_res','Y_res','Inches','Flash_Storage','Hybrid','HDD'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName            Cpu  Ram    Gpu       OpSys  Weight  Price  \
# 715      HP  Notebook  Intel Core i3    8  Intel  Windows 10    1.86  49389
#
#      IPS  Touchscreen  SSD  PPI
# 715    0            0  256  141

# %%
df.to_csv("laptop_cleaned_data.csv",index=False)

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
np.log(df['Price'])
# Out:
# 0       11.717954
# 1       11.318977
# 2       10.872124
# 3       12.356676
# 4       12.015299
#           ...
# 1219    10.976098
# 1220    11.830310
# 1221     9.951468
# 1222    11.156322
# 1223    10.428541
# Name: Price, Length: 1224, dtype: float64

# %%
sns.kdeplot(np.log(df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# np.exp(np.log(df['Price']))

# %%
# Outlier Detection
# Box

# %%
sns.boxplot(x=df['Price'])
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['Price'].describe()
# Out:
# count      1224.000000
# mean     103045.637255
# std       61378.407026
# min       15944.000000
# 25%       56160.000000
# 50%       89706.000000
# 75%      135383.750000
# max      448895.000000
# Name: Price, dtype: float64

# %%
((135383.750000-56160.000000)*1.5)+(135383.750000)
# Out:
# 254219.375

# %%
df[df['Price']>254219.375]
# Out:
#       Company            TypeName            Cpu  Ram     Gpu       OpSys  \
# 17      Apple           Ultrabook  Intel Core i7   16     AMD       MacOS
# 173       MSI              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 185    Lenovo  2 in 1 Convertible  Intel Core i7   16   Intel  Windows 10
# 196      Dell         Workstation     Intel Xeon   16  Nvidia  Windows 10
# 229      Asus              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 238      Asus              Gaming  Intel Core i7   16  Nvidia  Windows 10
# 288      Dell         Workstation  Intel Core i7   16  Nvidia  Windows 10
# 414      Dell              Gaming  Intel Core i7   16  Nvidia  Windows 10
# 473   Toshiba           Ultrabook  Intel Core i7   32   Intel  Windows 10
# 498      Asus              Gaming  Intel Core i7   24  Nvidia  Windows 10
# 511      Dell              Gaming  Intel Core i7   16  Nvidia  Windows 10
# 542    Lenovo            Notebook  Intel Core i7    8  Nvidia  Windows 10
# 585    Lenovo            Notebook     Intel Xeon   32  Nvidia  Windows 10
# 622      Asus              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 631      Dell              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 655      Dell              Gaming  Intel Core i7   16  Nvidia  Windows 10
# 692      Dell              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 713    Lenovo         Workstation  Intel Core i7   16  Nvidia  Windows 10
# 717        HP         Workstation     Intel Xeon   16  Nvidia   Windows 7
# 726      Dell              Gaming  Intel Core i7   16  Nvidia  Windows 10
# 744      Dell              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 795      Dell              Gaming  Intel Core i7   16  Nvidia  Windows 10
# 801      Dell              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 866        HP           Ultrabook   Intel Core M    8   Intel  Windows 10
# 910      Dell              Gaming  Intel Core i7   16  Nvidia  Windows 10
# 923      Dell              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 927      Dell              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 971    Lenovo            Notebook  Intel Core i7   16  Nvidia   Windows 7
# 1019     Asus              Gaming  Intel Core i7   64  Nvidia  Windows 10
# 1034   Lenovo              Gaming  Intel Core i7   32  Nvidia  Windows 10
# 1056       HP         Workstation  Intel Core i7    8     AMD   Windows 7
# 1087       HP         Workstation  Intel Core i7    8  Nvidia   Windows 7
#
#       Weight   Price  IPS  Touchscreen   SSD  PPI
# 17      1.83  261879    1            0   512  221
# 173     4.40  256472    0            0   512  120
# 185     1.42  258763    0            1  1000  210
# 196     2.80  279930    0            0   256  282
# 229     4.70  356441    0            0   512  127
# 238     3.60  274798    0            0   256  127
# 288     3.42  264340    0            0   256  127
# 414     4.42  256472    1            0   256  170
# 473     1.05  256472    0            1   512  166
# 498     2.24  271958    0            0   512  141
# 511     4.42  276060    1            0   128  127
# 542     3.40  274798    1            0   256  127
# 585     2.50  448895    1            0  1000  282
# 622     3.80  256472    1            0   512  127
# 631     4.42  288394    1            0   512  255
# 655     3.49  257824    0            0   256  141
# 692     4.36  335311    0            0  1000  255
# 713     2.50  302287    1            0  1000  282
# 717     3.00  402164    1            0   256  127
# 726     4.42  262886    1            0   256  282
# 744     4.42  328842    1            0  1000  127
# 795     3.21  254239    0            0   256  141
# 801     4.42  281569    1            0   512  127
# 866     1.09  284053    0            1   240  352
# 910     4.36  289001    1            0   512  255
# 923     4.42  288543    1            0   256  127
# 927     4.42  256564    0            0   256  127
# 971     2.40  271958    1            0   512  255
# 1019    3.58  364229    1            0  1000  127
# 1034    4.60  296881    1            0   512  127
# 1056    3.00  265635    1            0     0  127
# 1087    3.00  361884    1            0   256  127
